# %%
# !pip install wikitextparser
import funravel

# %%
#example 1: wiki, from https://en.wikipedia.org/wiki/Classic_Chinese_Novels
output = turn_text_into_table("""
{| class="wikitable" style="text-align:center"
! English !! Simplified Chinese !! Traditional Chinese !! Pinyin !! Attributed to !! Century
|-
|''[[Romance of the Three Kingdoms]]'' || {{lang|zh-hans|[[:zh:三国演义|三国演义]]}} || {{lang|zh-hant|三國演義}} || {{nowrap|{{lang|zh-Latn|Sānguó Yǎnyì}}}} || {{nowrap|[[Luo Guanzhong]]}} || 14th
|-
|''[[Water Margin]]'' || {{lang|zh-hans|[[:zh:水浒传|水浒传]]}} || {{lang|zh-hant|水滸傳}} || {{lang|zh-Latn|Shuǐhǔ Zhuàn}} || [[Shi Nai'an]]{{efn|There is considerable debate on the authorship of ''Water Margin''. While most attribute the novel to [[Shi Nai'an]], there were some who believe that the novel, or portions of it, was written by others, such as [[Luo Guanzhong]] (the author of ''[[Romance of the Three Kingdoms]]''), Shi Hui ({{lang|zh|施惠}}) and Guo Xun ({{lang|zh-hant|郭勛}}).}} || 14th
|-
|''[[Journey to the West]]'' || {{lang|zh-hans|[[:zh:西游记|西游记]]}} || {{lang|zh-hant|西遊記}} || {{lang|zh-Latn|Xī Yóu Jì}} || [[Wu Cheng'en]] || 16th
|-
|''[[Dream of the Red Chamber]]'' || {{lang|zh-hans|[[:zh:红楼梦|红楼梦]]}} || {{lang|zh-hant|紅樓夢}} || {{nowrap|{{lang|zh-Latn|Hónglóu Mèng}}}} || [[Cao Xueqin]] || 18th 
|}
""")
# Out:
# Since the text was not a valid file name, I assume it is the text to operate on.
#
# Input preview:
#
# {| class="wikitable" style="text-align:center"
# ! English !! Simplified Chinese !! Traditional Chinese !! Pinyin !! Attributed to !! Century
# |-
# |''[[Romance of the Three Kingdoms]]'' || {{lang|zh-hans|[[:zh:三国演义|三国演义]]}} || {{lang|zh-hant|三國演義}} || {{nowrap|{{lang|zh-Latn|Sānguó Yǎnyì}}}} || {{nowrap|[[Luo Guanzhong]]}} || 14th
# |-
# |''[[Water Margin]]'' || {{lang|zh-hans|[[:zh:水浒传|水浒传]]}} || {{lang|zh-hant|水滸傳}} || {{lang|zh-Latn|Shuǐhǔ Zhuàn}} || [[Shi Nai'an]]{{efn|There is considerable debate on the authorship of ''Water Margin''. While most attribute the novel to [[Shi Nai'an]], there were some who believe that the novel, or portions of it, was written by others, such as [[Luo Guanzhong]] (the author of ''[[Romance of the Three Kingdoms]]''), Shi Hui ({{lang|zh|施惠}}) and Guo Xun ({{lang|zh-hant|郭勛}}).}} || 14th
# |-
# ...

# %%
import matplotlib
matplotlib.pyplot.figure(figsize=(10, 4))
matplotlib.pyplot.plot(funravel.table[0][1:], funravel.table[5][1:])

# %%
#example 2: dictionary, from https://en.wikisource.org/wiki/The_Sign_Language/Chapter_3
output = turn_text_into_table("/content/the sign language a manual of signs 1918 by j schuyler long auxiliary verbs.txt")
# Out:
# Input preview:
# To Be, to Exist.—Hold the forefinger of the right "G" hand pointing upward, against the mouth; move the whole hand, finger still held upright, forward straight out from the mouth; then bring the "A" hands together, the end of the right thumb resting on the nail of the left thumb, and move both hands this way forward. (Note: This is the present and acceptable way to make this sign though formerly there were other signs. These are not here given, as it seems unnecessary.) The usual way is to make simply the first part of the sign with the forefinger, and then finish with "now" or "past" to indicate tense, and "many" to indicate plural. I,1.
#
# To Be, infinitive and imperative.—Hold the right "G" hand straight out in front from the side, the "G" up; crook the forefinger and move the hand toward the left side horizontally in front of the body. I, 2.
#
# ...

# %%
funravel.table
# Out:
#                                                     0                                                  1
# 0                                    To Be, to Exist.  Hold the forefinger of the right "G" hand poin...
# 1                   To Be, infinitive and imperative.  Hold the right "G" hand straight out in front ...
# 2              To Be, auxiliary of the passive voice.  Press the forefinger of the right "G" hand, po...
# 3            Can, expressing possibility, power, etc.  Hold the "S" hands out in front, elbows agains...
# 4                                              Can't.  Holding the left "G" hand out in front, strike...
# 5        May, Maybe, Perhaps, indicating probability.  Hold out both open hands in front straight fro...
# 6                         May, indicating permission.  Hold both open hands out in front straight fro...
# 7                     Should, Ought, indicating duty.  Press the crooked forefinger of the right "G" ...
# ...
